# %%
from azure.cognitiveservices.vision.customvision.training import CustomVisionTrainingClient
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateEntry
from msrest.authentication import ApiKeyCredentials

# %%
ENDPOINT = "Input your url"

training_key = "Input your key "
prediction_resource_id = "Input your key"

publish_iteration_name = "classifyModel"

credentials = ApiKeyCredentials(in_headers={"Training-key": training_key})
trainer = CustomVisionTrainingClient(ENDPOINT, credentials)

print ("Creating project...")
project = trainer.create_project("AzureMLHOL")
# Out:
# Creating project...

# %%
bb8_tag = trainer.create_tag(project.id, "bb8")
c3po_tag = trainer.create_tag(project.id, "c3po")
r2d2_tag = trainer.create_tag(project.id, "r2d2")

# %%
import os
path = 'image'
image_list =[]
for root, dirs, filenames in os.walk(path):
    for d in dirs:
        print('processing folder ' + d)     
        files = os.listdir(os.path.join(root,d))
        for f in files:
            # Open the file
            imgFile = os.path.join(root,d, f)
            print(imgFile)
            with open(imgFile, "rb") as image_contents:                
                if d=='r2d2':            
                    image_list.append(ImageFileCreateEntry(name=f, contents=image_contents.read(), tag_ids=[r2d2_tag.id]))      
                elif d=='c3po':
                    image_list.append(ImageFileCreateEntry(name=f, contents=image_contents.read(), tag_ids=[c3po_tag.id]))
                else:
                    image_list.append(ImageFileCreateEntry(name=f, contents=image_contents.read(), tag_ids=[bb8_tag.id]))
# Out:
# processing folder bb8
# image\bb8\img_00000001.jpg
# image\bb8\img_00000002.jpg
# image\bb8\img_00000004.jpg
# image\bb8\img_00000006.jpg
# image\bb8\img_00000007.jpg
# image\bb8\img_00000008.jpg
# image\bb8\img_00000009.jpg
# image\bb8\img_00000015.jpg
# image\bb8\img_00000016.jpg
# image\bb8\img_00000017.jpg
# image\bb8\img_00000018.jpg
# image\bb8\img_00000019.jpg
# image\bb8\img_00000020.jpg
# image\bb8\img_00000023.jpg
# image\bb8\img_00000024.jpg
# image\bb8\img_00000025.jpg
# image\bb8\img_00000026.jpg
# image\bb8\img_00000027.jpg
# image\bb8\img_00000029.jpg
# image\bb8\img_00000032.jpg
# image\bb8\img_00000033.jpg
# image\bb8\img_00000034.jpg
# image\bb8\img_00000035.jpg
# image\bb8\img_00000036.jpg
# image\bb8\img_00000039.jpg
# image\bb8\img_00000040.jpg
# image\bb8\img_00000041.jpg
# image\bb8\img_00000047.jpg
# image\bb8\img_00000048.jpg
# image\bb8\img_00000049.jpg
# image\bb8\img_00000051.jpg
# image\bb8\img_00000053.jpg
# image\bb8\img_00000055.jpg
# image\bb8\img_00000056.jpg
# image\bb8\img_00000059.jpg
# image\bb8\img_00000060.jpg
# image\bb8\img_00000061.jpg
# image\bb8\img_00000063.jpg
# image\bb8\img_00000064.jpg
# image\bb8\img_00000065.jpg
# image\bb8\img_00000066.jpg
# image\bb8\img_00000067.jpg
# image\bb8\img_00000068.jpg
# image\bb8\img_00000069.jpg
# image\bb8\img_00000070.jpg
# image\bb8\img_00000071.jpg
# image\bb8\img_00000072.jpg
# image\bb8\img_00000073.jpg
# image\bb8\img_00000074.jpg
# image\bb8\img_00000076.jpg
# image\bb8\img_00000077.jpg
# image\bb8\img_00000078.jpg
# image\bb8\img_00000079.jpg
# image\bb8\img_00000081.jpg
# image\bb8\img_00000084.jpg
# image\bb8\img_00000085.jpg
# image\bb8\img_00000086.jpg
# image\bb8\img_00000089.jpg
# image\bb8\img_00000090.jpg
# image\bb8\img_00000091.jpg
# image\bb8\img_00000093.jpg
# image\bb8\img_00000095.jpg
# image\r2d2\img_00000014.JPG
# image\r2d2\img_00000015.jpg
# image\r2d2\img_00000017.jpg
# image\r2d2\img_00000018.jpg
# image\r2d2\img_00000019.jpg
# image\r2d2\img_00000020.jpg
# image\r2d2\img_00000021.png
# image\r2d2\img_00000023.JPG
# image\r2d2\img_00000025.jpg
# image\r2d2\img_00000027.jpg
# image\r2d2\img_00000029.jpg
# image\r2d2\img_00000030.jpg
# image\r2d2\img_00000031.JPG
# image\r2d2\img_00000032.jpg
# image\r2d2\img_00000033.jpg
# image\r2d2\img_00000034.jpg
# image\r2d2\img_00000035.png
# image\r2d2\img_00000037.jpg
# image\r2d2\img_00000042.jpg
# image\r2d2\img_00000043.jpg
# image\r2d2\img_00000044.jpg
# image\r2d2\img_00000046.jpg
# image\r2d2\img_00000047.jpg
# image\r2d2\img_00000048.jpg
# image\r2d2\img_00000049.jpg
# image\r2d2\img_00000050.jpg
# image\r2d2\img_00000051.jpg
# image\r2d2\img_00000053.jpg
# image\r2d2\img_00000054.jpg
# image\r2d2\img_00000055.jpg
# image\r2d2\img_00000056.jpg
# image\r2d2\img_00000057.jpg
# image\r2d2\img_00000058.jpg
# image\r2d2\img_00000059.JPG
# image\r2d2\img_00000060.jpg
# image\r2d2\img_00000061.JPG
# image\r2d2\img_00000063.jpg
# image\r2d2\img_00000064.jpg
# image\r2d2\img_00000065.jpg
# image\r2d2\img_00000068.JPG
# image\r2d2\img_00000069.JPG
# image\r2d2\img_00000070.jpg
# image\r2d2\img_00000071.jpg
# image\r2d2\img_00000072.jpg
# image\r2d2\img_00000074.jpg
# image\r2d2\img_00000075.jpg
# image\r2d2\img_00000076.jpg
# image\r2d2\img_00000078.JPG
# image\r2d2\img_00000079.jpg
# image\r2d2\img_00000080.jpg
# image\r2d2\img_00000081.png
# image\r2d2\img_00000082.jpg
# image\r2d2\img_00000084.jpg
# image\r2d2\img_00000085.jpg
# image\r2d2\img_00000086.jpg
# image\r2d2\img_00000087.jpg
# image\r2d2\img_00000088.jpg
# image\r2d2\img_00000089.jpg
# image\r2d2\img_00000090.jpg
# image\r2d2\img_00000091.jpg
# image\r2d2\img_00000093.jpg
# image\r2d2\img_00000094.JPG
# image\r2d2\img_00000095.jpg
# image\r2d2\img_00000096.jpg
# image\r2d2\img_00000097.jpg
# image\r2d2\img_00000099.JPG
# image\r2d2\img_00000100.jpg

# %%
from azure.cognitiveservices.vision.customvision.training.models import ImageFileCreateBatch
imgSize = int(len(image_list)/64)
imgPage = len(image_list)%64

for i in range(imgSize):
    print(i)
    list = image_list[i*64 : (i+1)*64]
    upload_result = trainer.create_images_from_files(project.id, ImageFileCreateBatch(images= list))
    if not upload_result.is_batch_successful:
        for image in upload_result.images:
            print("Image status: ", image.status)
        exit(-1)
# Out:
# 0
# 1
# 2
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OKDuplicate
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK

# %%
if imgPage > 0 :
    list = image_list[imgSize*64 : imgSize*64 + imgPage]
    upload_result = trainer.create_images_from_files(project.id, ImageFileCreateBatch(images= list))
    if not upload_result.is_batch_successful:
        for image in upload_result.images:
            print("Image status: ", image.status)
        exit(-1)
# Out:
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OKDuplicate
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK
# Image status:  OK

# %%
import time

print ("Training...")
iteration = trainer.train_project(project.id)
while (iteration.status != "Completed"):
    iteration = trainer.get_iteration(project.id, iteration.id)
    print ("Training status: " + iteration.status)
    time.sleep(1)

trainer.publish_iteration(project.id, iteration.id, publish_iteration_name, prediction_resource_id)
print ("Done!")
# Out:
# Training...
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
# Training status: Training
