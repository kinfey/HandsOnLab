# %%
# !pip3 install srt
# Out:
# Requirement already satisfied: srt in c:\users\kinfeylo\appdata\local\programs\python\python38\lib\site-packages (3.4.1)

# %%
import azure.cognitiveservices.speech as speechsdk
import os
import time
import pprint
import json
import srt
import datetime

# %%
speech_key, service_region = "1977ff7bd14e4f779e892c68466fea2d", "eastasia"
speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)

# %%
audio_input = speechsdk.AudioConfig(filename="./gpu.wav")

# %%
speech_config.speech_recognition_language="zh-CN"
speech_config.request_word_level_timestamps()

speech_config.enable_dictation()
speech_config.output_format = speechsdk.OutputFormat(1)

speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, audio_config=audio_input)

# %%
all_results = []
results = []
transcript = []
words = []

# %%
def handle_final_result(evt):
    import json
    all_results.append(evt.result.text) 
    results = json.loads(evt.result.json)
    transcript.append(results['DisplayText'])
    confidence_list_temp = [item.get('Confidence') for item in results['NBest']]
    max_confidence_index = confidence_list_temp.index(max(confidence_list_temp))
    words.extend(results['NBest'][max_confidence_index]['Words'])

# %%
done = False

def stop_cb(evt):
    print('CLOSING on {}'.format(evt))
    speech_recognizer.stop_continuous_recognition()
    global done
    done= True

# %%
speech_recognizer.recognized.connect(handle_final_result) 
#Connect callbacks to the events fired by the speech recognizer    
# speech_recognizer.recognizing.connect(lambda evt: print('RECOGNIZING: {}'.format(evt)))
speech_recognizer.recognized.connect(lambda evt: print('RECOGNIZED: {}'.format(evt)))
# speech_recognizer.session_started.connect(lambda evt: print('SESSION STARTED: {}'.format(evt)))
# speech_recognizer.session_stopped.connect(lambda evt: print('SESSION STOPPED {}'.format(evt)))
# speech_recognizer.canceled.connect(lambda evt: print('CANCELED {}'.format(evt)))
# stop continuous recognition on either session stopped or canceled events
speech_recognizer.session_stopped.connect(stop_cb)
speech_recognizer.canceled.connect(stop_cb)

# %%
speech_recognizer.start_continuous_recognition()

while not done:
    time.sleep(.5)
# Out:
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=75d6f7c1f5a741cebe046d86e1210291, text="哦哦今天我想给各位同学来介绍一下Azure机器学习的一个部分。那如果大家呢，呃，有看上面的小视频呢？大家会知道，Azure上面呢，有非常呃，强大的一些机器学习的一些功能啊啊。我们，呃，之前呢就介绍过一个零代码的方式去做。呃，一个计算机视觉的任务，那接下来呢？我想给大家更专业的部分，大家知道我们做机器学习的时候呢，会遇到一个状况，就是，呃，我们可能没有GPU。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=b185ebf84f8d45b39f31a0079c5c5337, text="或者是没有一些机器学习的平台，还有搭建环境的时候非常不方便。但是如果你通过Azure了，可以很快速的去完成相关的工作，你可以不需要关注你的整个。呃，平台的一些搭建情况啊啊，安装啊，配置文件之类的就可以启动你的Azure的一些机器学习上面的一些服务，包括说logo，包括说Python的环境，还有就是一些GPU的一些算力的一些呃，使用在这里面的话呢，我想给大家介绍一下。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=63cfb9efc7f74234ae9bf75aabb6650f, text="Azure的整个，呃，机器学习的一个服务的一个平台好。首先呢，我们回到Azure的portal里面，在这个坡头里面呢？呃，会有很多的一些呃资资源的一些创建，我们呢，首先还是要去创建一个Azure，去关于机器服务的，呃，资源，我们去选择AI加机器学习，然后呢在这里面定义列，呃，里面的。呃，第一个就是我们的机器学习服务，然后点击创建，那这个收了它就会引导你去做一个Azure的一个机器学习的一个。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=5a9a636f6a514dfd8db7cdf2a192edbb, text="创建在这里面的话，你可以选择的是原有的资源组或者是自己可以新建一个另外的你可能是要去创建一个机器学习的一个名字。呃，像L demo。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=0e6dcef6e07e4fda8d501b0053d7f6f1, text="哦然后呢，你可以选择你的区域，然后你的存储的账户为什么要有存储呢？因为呃，在里面的话，它可以帮你去保存你的。呃，朱比特的logo还有相关的一些，呃，关于数据的整理啊，呃还有另外的一些相关的。呃，包括说训练的一些操作。还有就是一些，呃，密钥啊啊，这些都是一个非常有用的。当然你需不需要去注册一个容器了啊，也可以默认可以不用啊，在这里我们先不用，然后就开始去创建了。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=e2e54c81e3e34a509b86e516051d5e2a, text="那在创建的过程当中，他会去也是做我们的验证的步骤。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=917c712de4d44c5b83fd745caa73dcb9, text="稍等，如果验证通过的话你就可以直接的去创建了。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=6e140a57ff6b4cdfbd67e04881c7f040, text="当然你的。呃。Azure machine Learning的服务呢呃，已经创建好之后呢，他就会可以告诉你去转到相关的资源里面。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=845af6d8a71f4894a066fdc67bd4341e, text="那大家可以看得到呃，在这里面的话，他已经把你需要的资源组已经绑定了，当然也在存储的空间还有位置上面都做了一些绑定啊，在这里面你就可以直接的去使用你的Azure machine Learning的一个平台，在这上面的话啊，我们可以根据呃情况呢去点击啊啊，这个工作室里面的URL啊，去跳转到我们的Azure机器服务的一个呃相关的一个连接，那这个时候你就可以根据你的需要。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=313fca317f6a4ea0aed773e9949ca018, text="去创建爱你的呃一些公呃，跟机器学习相关的一些工作。举个例子，呃，我们做机器学习可能需要到logo。那你这个时候你可能是要去。呃。做logo的操作啊，在这里面你可以去添加啊新的logo也可以呢。呃，去在sample里面，因为你是要去学习，那你可以在上面去，呃，学习一个，呃，添加一个呃。相关的一个怎么样子去用ml experiment的操作，那这个时候呢，你可以去X sample的一个文件夹里面。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=dd7d4de130374fec9a340f605a151195, text="啊，去把它克隆到你的本地上面。像举个例子，我在这里是一个Looking费的一个目录啊，是我的名字，然后就克隆。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=67d1ef9fadf14bde8e0f88039d32680b, text="他就可以把呃，sample里面的文件，呃，克隆道理的呃，一个目录上面然后呢在这下面的话好像说我要去。呃，乱我的一个SDK AML的SDK，那我点击他的文件的时候大家可以发现啊，他的M啊，都是英文，比较高大上，但是不怕啊啊。在上面的话呢，呃，都是一些怎么样子去，呃，利用。嗯，这个Azure machine Learning去做一些模型训练的，那这个时候大家知道你需要去做一些相关的一些算力。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=265e8e820777427e919427684825a825, text="呃，那你这个收了，他会告诉你你没有去做算力怎么办呢？你要去选择一个，呃，新的一个compute啊啊。在这里面你可以选择的是GPU跟CPU的compute，因为我在这里的话啊，是，呃，有你可以用一个叫做M选择GPU的时候，你可以选择的是，呃，一个M60的一个GPU的一个算力。当然你如果是节省一点的话，因为你有学生账号啊，有100刀的一个，呃，算力的一个支持。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=3cb17101bd1841a7854f42efd00d18e2, text="那这个时候呢，你可以选择啊，一个GPU啊啊，每个小时来算就1.58美金啊，1.5百558刀啊啊的一个算力啊。所以在这里面的话啊，你可以根据你的需要去做，而且这个呢，你不用的时候把它停掉，它是不算任何费用的。所以呢，你要看你自己的实际情况，当然你可以用CPU CPU的话呢，它有很多的cu的，呃，算力在上面像我在这里的话，我就用了一个叫做DS3 V2的一个。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=28655a57ac89449d9a01463ea30e09de, text="呃，普通的一个CPU，它是0.14刀啊呃四一刀啊呃，作为每个小时的算力那我就在这里创建创建也是虚实，呃，去创建啊。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=84b70ea8823445e38aa17696645f12e2, text="呃，它会创建成功之后就会告诉你哦，这个东西是怎么样子的，嗯。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=33ef126bd45c4fa4a72f721ccc2a15b3, text="大家可以看得到哈哦你的算力也不需要去投入啊。而且呢，你可以去呃，做很多的一些机器学习相关的工作。另外呢，在这里面我想介绍给大家一个非常好玩的东西，就是他的比赛呢，我们在等待计算嗯的这个算力呃，创启动起来的时候呢，你就可以去看一下这个比赛了，这个比赛呢是什么东西呢？大家知道在Windows上面，嗯，我们可以。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=fcf1e4ab8f1c4d719c018b7e48e5e567, text="很简单的去拖拽一些控件去完成一些Windows的界面啊。在这里面的话呢，你可以通过啊相关的，呃，一个，呃，拖拽呃去完成机器学习里面相关的一些知识的一些创建，像我在这里的话，大家可以看到我，我选择了一个图像识别的操作之后呢，呃，如果你选择这个比赛呢，你可以看到它从图图像集啊到图像的一些转变到图像图片的一些分类。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=c11186b9b2074128806925963312392f, text="爱到训练，都是通过拖拽去完成的。这样子的话呢，他就让机器学习更加的呃，自动化啊可视化啊。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=b6abbd2fc68b42a8a553d2a64b2b490b, text="呃，所以呢？呃，通过Azure的机器学习服务了你可以，呃，通过设计器去完成你的机器学习的步骤。另外的也还可以用业界最受欢迎的auto ml去完成相关的任务，也是非常方便可用的。然后我们回到我们的logo去看一下他是不是已经创建完了。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=0b631dc0a120462390a0628cb2d6d541, text="好，当我们的算力创建完之后啊，大家可以看得到他会去提醒你哦，这个算力已经创建成功了然后在这个时候呢？呃，大家会担心的是，哎呀我这个算力究竟是用三者环境举个例子，你可以用的是Python 3.6的环境，当然也可以用3.8啊，还有另外的它也支持R的这种算力的一个支持。所以呢，在这里面呢是非常方便的啊，而且你可以通过呃logo的去线上的这个logo呢去添加代码。", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=7503d5a71b2840dab27d025bbe1f8448, text="然后运行。所以呢，通过Azure machine Learning的服务呢？呃，可以让你的机器学习了的呃，学习或者实验的环境呢，得到一个提升。而且是在，呃，不用付费的前提下去完成这个事啊。希望各位同学了啊，马上去尝试一下啊。呃，通过Azure的机器学习服务去完成你的，呃，AI的学习啊，也可以作为学习的环境啊，谢谢大家。", reason=ResultReason.RecognizedSpeech))
# CLOSING on SpeechRecognitionCanceledEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c, result=SpeechRecognitionResult(result_id=980a5a70fb294791aac79ce187bd845a, text="", reason=ResultReason.Canceled))
# CLOSING on SessionEventArgs(session_id=a3a37618b94c42db93125abc17e62d3c)

# %%
print("Printing all results:")
print(all_results)

speech_to_text_response = words
# Out:
# Printing all results:
# ['哦哦今天我想给各位同学来介绍一下Azure机器学习的一个部分。那如果大家呢，呃，有看上面的小视频呢？大家会知道，Azure上面呢，有非常呃，强大的一些机器学习的一些功能啊啊。我们，呃，之前呢就介绍过一个零代码的方式去做。呃，一个计算机视觉的任务，那接下来呢？我想给大家更专业的部分，大家知道我们做机器学习的时候呢，会遇到一个状况，就是，呃，我们可能没有GPU。', '或者是没有一些机器学习的平台，还有搭建环境的时候非常不方便。但是如果你通过Azure了，可以很快速的去完成相关的工作，你可以不需要关注你的整个。呃，平台的一些搭建情况啊啊，安装啊，配置文件之类的就可以启动你的Azure的一些机器学习上面的一些服务，包括说logo，包括说Python的环境，还有就是一些GPU的一些算力的一些呃，使用在这里面的话呢，我想给大家介绍一下。', 'Azure的整个，呃，机器学习的一个服务的一个平台好。首先呢，我们回到Azure的portal里面，在这个坡头里面呢？呃，会有很多的一些呃资资源的一些创建，我们呢，首先还是要去创建一个Azure，去关于机器服务的，呃，资源，我们去选择AI加机器学习，然后呢在这里面定义列，呃，里面的。呃，第一个就是我们的机器学习服务，然后点击创建，那这个收了它就会引导你去做一个Azure的一个机器学习的一个。', '创建在这里面的话，你可以选择的是原有的资源组或者是自己可以新建一个另外的你可能是要去创建一个机器学习的一个名字。呃，像L demo。', '哦然后呢，你可以选择你的区域，然后你的存储的账户为什么要有存储呢？因为呃，在里面的话，它可以帮你去保存你的。呃，朱比特的logo还有相关的一些，呃，关于数据的整理啊，呃还有另外的一些相关的。呃，包括说训练的一些操作。还有就是一些，呃，密钥啊啊，这些都是一个非常有用的。当然你需不需要去注册一个容器了啊，也可以默认可以不用啊，在这里我们先不用，然后就开始去创建了。', '那在创建的过程当中，他会去也是做我们的验证的步骤。', '稍等，如果验证通过的话你就可以直接的去创建了。', '当然你的。呃。Azure machine Learning的服务呢呃，已经创建好之后呢，他就会可以告诉你去转到相关的资源里面。', '那大家可以看得到呃，在这里面的话，他已经把你需要的资源组已经绑定了，当然也在存储的空间还有位置上面都做了一些绑定啊，在这里面你就可以直接的去使用你的Azure machine Learning的一个平台，在这上面的话啊，我们可以根据呃情况呢去点击啊啊，这个工作室里面的URL啊，去跳转到我们的Azure机器服务的一个呃相关的一个连接，那这个时候你就可以根据你的需要。', '去创建爱你的呃一些公呃，跟机器学习相关的一些工作。举个例子，呃，我们做机器学习可能需要到logo。那你这个时候你可能是要去。呃。做logo的操作啊，在这里面你可以去添加啊新的logo也可以呢。呃，去在sample里面，因为你是要去学习，那你可以在上面去，呃，学习一个，呃，添加一个呃。相关的一个怎么样子去用ml experiment的操作，那这个时候呢，你可以去X sample的一个文件夹里面。', '啊，去把它克隆到你的本地上面。像举个例子，我在这里是一个Looking费的一个目录啊，是我的名字，然后就克隆。', '他就可以把呃，sample里面的文件，呃，克隆道理的呃，一个目录上面然后呢在这下面的话好像说我要去。呃，乱我的一个SDK AML的SDK，那我点击他的文件的时候大家可以发现啊，他的M啊，都是英文，比较高大上，但是不怕啊啊。在上面的话呢，呃，都是一些怎么样子去，呃，利用。嗯，这个Azure machine Learning去做一些模型训练的，那这个时候大家知道你需要去做一些相关的一些算力。', '呃，那你这个收了，他会告诉你你没有去做算力怎么办呢？你要去选择一个，呃，新的一个compute啊啊。在这里面你可以选择的是GPU跟CPU的compute，因为我在这里的话啊，是，呃，有你可以用一个叫做M选择GPU的时候，你可以选择的是，呃，一个M60的一个GPU的一个算力。当然你如果是节省一点的话，因为你有学生账号啊，有100刀的一个，呃，算力的一个支持。', '那这个时候呢，你可以选择啊，一个GPU啊啊，每个小时来算就1.58美金啊，1.5百558刀啊啊的一个算力啊。所以在这里面的话啊，你可以根据你的需要去做，而且这个呢，你不用的时候把它停掉，它是不算任何费用的。所以呢，你要看你自己的实际情况，当然你可以用CPU CPU的话呢，它有很多的cu的，呃，算力在上面像我在这里的话，我就用了一个叫做DS3 V2的一个。', '呃，普通的一个CPU，它是0.14刀啊呃四一刀啊呃，作为每个小时的算力那我就在这里创建创建也是虚实，呃，去创建啊。', '呃，它会创建成功之后就会告诉你哦，这个东西是怎么样子的，嗯。', '大家可以看得到哈哦你的算力也不需要去投入啊。而且呢，你可以去呃，做很多的一些机器学习相关的工作。另外呢，在这里面我想介绍给大家一个非常好玩的东西，就是他的比赛呢，我们在等待计算嗯的这个算力呃，创启动起来的时候呢，你就可以去看一下这个比赛了，这个比赛呢是什么东西呢？大家知道在Windows上面，嗯，我们可以。', '很简单的去拖拽一些控件去完成一些Windows的界面啊。在这里面的话呢，你可以通过啊相关的，呃，一个，呃，拖拽呃去完成机器学习里面相关的一些知识的一些创建，像我在这里的话，大家可以看到我，我选择了一个图像识别的操作之后呢，呃，如果你选择这个比赛呢，你可以看到它从图图像集啊到图像的一些转变到图像图片的一些分类。', '爱到训练，都是通过拖拽去完成的。这样子的话呢，他就让机器学习更加的呃，自动化啊可视化啊。', '呃，所以呢？呃，通过Azure的机器学习服务了你可以，呃，通过设计器去完成你的机器学习的步骤。另外的也还可以用业界最受欢迎的auto ml去完成相关的任务，也是非常方便可用的。然后我们回到我们的logo去看一下他是不是已经创建完了。', '好，当我们的算力创建完之后啊，大家可以看得到他会去提醒你哦，这个算力已经创建成功了然后在这个时候呢？呃，大家会担心的是，哎呀我这个算力究竟是用三者环境举个例子，你可以用的是Python 3.6的环境，当然也可以用3.8啊，还有另外的它也支持R的这种算力的一个支持。所以呢，在这里面呢是非常方便的啊，而且你可以通过呃logo的去线上的这个logo呢去添加代码。', '然后运行。所以呢，通过Azure machine Learning的服务呢？呃，可以让你的机器学习了的呃，学习或者实验的环境呢，得到一个提升。而且是在，呃，不用付费的前提下去完成这个事啊。希望各位同学了啊，马上去尝试一下啊。呃，通过Azure的机器学习服务去完成你的，呃，AI的学习啊，也可以作为学习的环境啊，谢谢大家。']

# %%
def convertduration(t):
    x= t/10000
    return int((x / 1000)), (x % 1000)

# %%
bin = 3
duration = 0 
transcriptions = []
transcript = ""
index,prev=0,0
wordstartsec,wordstartmicrosec=0,0
for i in range(len(speech_to_text_response)):
    #Forms the sentence until the bin size condition is met
    transcript = transcript  + speech_to_text_response[i]["Word"]
    print(transcript)
    #Checks whether the elapsed duration is less than the bin size
    if(int((duration / 10000000)) < bin): 
        wordstartsec,wordstartmicrosec=convertduration(speech_to_text_response[i]["Offset"])
        duration= duration+speech_to_text_response[i]["Offset"]-prev
        prev=speech_to_text_response[i]["Offset"]
        # transcript = transcript + " " + speech_to_text_response[i]["Word"]
        # print(wordstartmicrosec)
    else : 
        index=index+1
        #transcript = transcript + " " + speech_to_text_response[i]["Word"]
        # transcript = transcript + " " + speech_to_text_response[i]["Word"]
        # print(transcript)
        transcriptions.append(srt.Subtitle(index, datetime.timedelta(0, wordstartsec, wordstartmicrosec), datetime.timedelta(0, wordstartsec+bin, 0), transcript))
        duration = 0 
        #print(transcript)
        transcript=""
# Out:
# 哦哦
# 哦哦今天
# 哦哦今天我想
# 给
# 给各位
# 给各位同学
# 给各位同学来
# 给各位同学来介绍
# 给各位同学来介绍一下
# 给各位同学来介绍一下azure
# 给各位同学来介绍一下azure机器学习
# 的一个
# 的一个部分
# 的一个部分那
# 的一个部分那如果
# 的一个部分那如果大家
# 的一个部分那如果大家呢
# 呃
# 呃有
# 呃有看上
# 呃有看上面
# 呃有看上面的
# 呃有看上面的小视
# 呃有看上面的小视频
# 呃有看上面的小视频呢
# 呃有看上面的小视频呢大家
# 呃有看上面的小视频呢大家会
# 呃有看上面的小视频呢大家会知道
# 呃有看上面的小视频呢大家会知道azure
# 呃有看上面的小视频呢大家会知道azure上面
# 呢
# 呢有
# 呢有非常
# 呢有非常呃
# 呢有非常呃强大
# 呢有非常呃强大的
# 呢有非常呃强大的一些
# 呢有非常呃强大的一些机器学习
# 呢有非常呃强大的一些机器学习的
# 一些
# 一些功能
# 一些功能啊
# 一些功能啊啊
# 一些功能啊啊我们
# 一些功能啊啊我们呃
# 一些功能啊啊我们呃之前
# 呢
# 呢就
# 呢就介绍
# 呢就介绍过
# 呢就介绍过一个
# 呢就介绍过一个零
# 呢就介绍过一个零代码
# 呢就介绍过一个零代码的
# 呢就介绍过一个零代码的方式
# 呢就介绍过一个零代码的方式去
# 呢就介绍过一个零代码的方式去做
# 呢就介绍过一个零代码的方式去做呃
# 一个
# 一个计算机
# 一个计算机视觉
# 一个计算机视觉的
# 一个计算机视觉的任务
# 一个计算机视觉的任务那
# 一个计算机视觉的任务那接下来
# 一个计算机视觉的任务那接下来呢
# 一个计算机视觉的任务那接下来呢我想
# 给
# 给大家
# 给大家更
# 给大家更专业
# 给大家更专业的
# 给大家更专业的部分
# 给大家更专业的部分大家
# 给大家更专业的部分大家知道
# 给大家更专业的部分大家知道我们
# 给大家更专业的部分大家知道我们做
# 机器学习
# 机器学习的
# 机器学习的时候
# 机器学习的时候呢
# 机器学习的时候呢会
# 机器学习的时候呢会遇到
# 机器学习的时候呢会遇到一个
# 机器学习的时候呢会遇到一个状况
# 机器学习的时候呢会遇到一个状况就是
# 机器学习的时候呢会遇到一个状况就是呃
# 我们
# 我们可能
# 我们可能没有
# 我们可能没有gpu
# 我们可能没有gpu或者
# 我们可能没有gpu或者是
# 我们可能没有gpu或者是没有
# 我们可能没有gpu或者是没有一些
# 机器学习
# 机器学习的
# 机器学习的平台
# 机器学习的平台还有
# 机器学习的平台还有搭建
# 机器学习的平台还有搭建环境
# 机器学习的平台还有搭建环境的
# 机器学习的平台还有搭建环境的时候
# 机器学习的平台还有搭建环境的时候非常
# 不
# 不方便
# 不方便但是
# 不方便但是如果你
# 不方便但是如果你通过
# 不方便但是如果你通过azure
# 不方便但是如果你通过azure了
# 不方便但是如果你通过azure了可以
# 不方便但是如果你通过azure了可以很快
# 速
# 速地
# 速地去
# 速地去完成
# 速地去完成相关
# 速地去完成相关的
# 速地去完成相关的工作
# 速地去完成相关的工作你
# 速地去完成相关的工作你可以不
# 需要
# 需要关注
# 需要关注你的
# 需要关注你的整个
# 需要关注你的整个呃
# 需要关注你的整个呃平台
# 需要关注你的整个呃平台的
# 需要关注你的整个呃平台的一些
# 搭建
# 搭建情况
# 搭建情况啊
# 搭建情况啊啊
# 搭建情况啊啊安装
# 搭建情况啊啊安装啊
# 搭建情况啊啊安装啊配置文件
# 搭建情况啊啊安装啊配置文件之类
# 搭建情况啊啊安装啊配置文件之类的
# 就可以
# 就可以启动
# 就可以启动你的
# 就可以启动你的azure
# 就可以启动你的azure的
# 就可以启动你的azure的一些
# 就可以启动你的azure的一些机器学习
# 就可以启动你的azure的一些机器学习上面
# 就可以启动你的azure的一些机器学习上面的
# 一些服务
# 一些服务包括
# 一些服务包括说
# 一些服务包括说logo
# 一些服务包括说logo包括
# 一些服务包括说logo包括说
# 一些服务包括说logo包括说python
# 一些服务包括说logo包括说python的
# 环境
# 环境还有
# 环境还有就是
# 环境还有就是一些
# 环境还有就是一些gpu
# 环境还有就是一些gpu的
# 环境还有就是一些gpu的一些
# 环境还有就是一些gpu的一些算
# 环境还有就是一些gpu的一些算力
# 环境还有就是一些gpu的一些算力的
# 一些
# 一些呃
# 一些呃使用
# 一些呃使用在这里
# 一些呃使用在这里面
# 一些呃使用在这里面的话
# 一些呃使用在这里面的话呢
# 一些呃使用在这里面的话呢我想
# 一些呃使用在这里面的话呢我想给
# 一些呃使用在这里面的话呢我想给大家
# 一些呃使用在这里面的话呢我想给大家介绍
# 一些呃使用在这里面的话呢我想给大家介绍一下
# azure
# azure的
# azure的整个
# azure的整个呃
# azure的整个呃机器学习
# azure的整个呃机器学习的一个
# azure的整个呃机器学习的一个服务
# azure的整个呃机器学习的一个服务的一个
# 平台
# 平台好
# 平台好首先
# 平台好首先呢
# 平台好首先呢我们
# 平台好首先呢我们回到
# 平台好首先呢我们回到azure
# 平台好首先呢我们回到azure的
# 平台好首先呢我们回到azure的portal
# 里面
# 里面在这
# 里面在这个
# 里面在这个坡头
# 里面在这个坡头里面
# 里面在这个坡头里面呢
# 里面在这个坡头里面呢呃
# 里面在这个坡头里面呢呃会有
# 里面在这个坡头里面呢呃会有很多
# 里面在这个坡头里面呢呃会有很多的
# 一些
# 一些呃
# 一些呃资
# 一些呃资资源
# 一些呃资资源的
# 一些呃资资源的一些
# 一些呃资资源的一些创建
# 一些呃资资源的一些创建我们
# 一些呃资资源的一些创建我们呢
# 首先
# 首先还是
# 首先还是要去
# 首先还是要去创建
# 首先还是要去创建一个
# 首先还是要去创建一个azure
# 首先还是要去创建一个azure及
# 首先还是要去创建一个azure及关于
# 首先还是要去创建一个azure及关于机器
# 服务
# 服务的
# 服务的呃
# 服务的呃资源
# 服务的呃资源我们
# 服务的呃资源我们去
# 服务的呃资源我们去选择
# 服务的呃资源我们去选择ai
# 加
# 加机器学习
# 加机器学习然后
# 加机器学习然后呢
# 加机器学习然后呢在这里
# 加机器学习然后呢在这里面
# 加机器学习然后呢在这里面定义
# 列
# 列呃
# 列呃里面的
# 列呃里面的呃
# 列呃里面的呃第一个
# 列呃里面的呃第一个就是我
# 列呃里面的呃第一个就是我们
# 的
# 的机器学习
# 的机器学习服务
# 的机器学习服务然后
# 的机器学习服务然后点击
# 的机器学习服务然后点击创建
# 的机器学习服务然后点击创建那
# 的机器学习服务然后点击创建那这个
# 收
# 收了
# 收了他
# 收了他就会
# 收了他就会引导
# 收了他就会引导你去
# 收了他就会引导你去做一个
# 收了他就会引导你去做一个azure
# 收了他就会引导你去做一个azure的一个
# 收了他就会引导你去做一个azure的一个机器学习
# 的一个
# 的一个创建
# 的一个创建在这里
# 的一个创建在这里面
# 的一个创建在这里面的话
# 的一个创建在这里面的话你
# 的一个创建在这里面的话你可以
# 选择
# 选择的
# 选择的是
# 选择的是原有
# 选择的是原有的
# 选择的是原有的资源
# 选择的是原有的资源组
# 选择的是原有的资源组或者
# 选择的是原有的资源组或者是
# 选择的是原有的资源组或者是自己
# 可以
# 可以新建
# 可以新建一个
# 可以新建一个另外的
# 可以新建一个另外的你
# 可以新建一个另外的你可能
# 可以新建一个另外的你可能是要
# 可以新建一个另外的你可能是要去
# 可以新建一个另外的你可能是要去创建
# 一个
# 一个机器学习
# 一个机器学习的一个
# 一个机器学习的一个名字
# 一个机器学习的一个名字呃
# 一个机器学习的一个名字呃像
# 一个机器学习的一个名字呃像l
# 一个机器学习的一个名字呃像ldemo
# 哦
# 哦然后
# 哦然后呢
# 哦然后呢你
# 可以
# 可以选择
# 可以选择你的
# 可以选择你的区域
# 可以选择你的区域然后
# 可以选择你的区域然后你的
# 可以选择你的区域然后你的存储
# 可以选择你的区域然后你的存储的
# 可以选择你的区域然后你的存储的账户
# 可以选择你的区域然后你的存储的账户为什么
# 可以选择你的区域然后你的存储的账户为什么要有
# 存储
# 存储呢
# 存储呢因为
# 存储呢因为呃
# 存储呢因为呃在
# 存储呢因为呃在里面的
# 存储呢因为呃在里面的话
# 存储呢因为呃在里面的话它
# 存储呢因为呃在里面的话它可以
# 存储呢因为呃在里面的话它可以帮你
# 去
# 去保存
# 去保存你的
# 去保存你的呃
# 去保存你的呃朱
# 去保存你的呃朱比特
# 去保存你的呃朱比特的
# 去保存你的呃朱比特的logo
# 去保存你的呃朱比特的logo还有
# 去保存你的呃朱比特的logo还有相关
# 去保存你的呃朱比特的logo还有相关的
# 一些
# 一些呃
# 一些呃关于
# 一些呃关于数据
# 一些呃关于数据的
# 一些呃关于数据的整理
# 一些呃关于数据的整理啊
# 一些呃关于数据的整理啊呃
# 一些呃关于数据的整理啊呃还有
# 一些呃关于数据的整理啊呃还有另外的
# 一些
# 一些相关
# 一些相关的
# 一些相关的呃
# 一些相关的呃包括
# 一些相关的呃包括说
# 一些相关的呃包括说训练
# 一些相关的呃包括说训练的
# 一些相关的呃包括说训练的一些
# 一些相关的呃包括说训练的一些操作
# 还有
# 还有就是
# 还有就是一些
# 还有就是一些呃
# 还有就是一些呃密钥
# 还有就是一些呃密钥啊
# 还有就是一些呃密钥啊啊
# 这些
# 这些都是
# 这些都是一个
# 这些都是一个非常
# 这些都是一个非常有用
# 这些都是一个非常有用的
# 这些都是一个非常有用的当然
# 这些都是一个非常有用的当然你
# 这些都是一个非常有用的当然你需不需要
# 这些都是一个非常有用的当然你需不需要去
# 注册
# 注册一个
# 注册一个容器
# 注册一个容器了啊
# 注册一个容器了啊也可以
# 注册一个容器了啊也可以默认
# 注册一个容器了啊也可以默认可以不
# 用
# 用啊
# 用啊在这里
# 用啊在这里我们
# 用啊在这里我们先
# 用啊在这里我们先不用
# 用啊在这里我们先不用然后
# 用啊在这里我们先不用然后就
# 用啊在这里我们先不用然后就开始
# 去
# 去创建
# 去创建了
# 去创建了那
# 去创建了那在
# 去创建了那在创建
# 的
# 的过程
# 的过程当中
# 的过程当中他
# 的过程当中他会去
# 的过程当中他会去也是
# 的过程当中他会去也是做
# 的过程当中他会去也是做我们的
# 的过程当中他会去也是做我们的验证
# 的过程当中他会去也是做我们的验证的
# 步骤
# 步骤稍等
# 步骤稍等如果
# 验证
# 验证通过
# 验证通过的话
# 验证通过的话你
# 验证通过的话你就可以
# 验证通过的话你就可以直接
# 验证通过的话你就可以直接的
# 验证通过的话你就可以直接的去
# 验证通过的话你就可以直接的去创建
# 验证通过的话你就可以直接的去创建了
# 验证通过的话你就可以直接的去创建了当
# 安妮
# 安妮的
# 呃
# 呃azure
# 呃azuremachine
# 呃azuremachinelearning
# 呃azuremachinelearning的
# 呃azuremachinelearning的服务
# 呃azuremachinelearning的服务了
# 呃azuremachinelearning的服务了呃
# 已经
# 已经创建
# 已经创建了
# 已经创建了之后
# 已经创建了之后呢
# 已经创建了之后呢他
# 已经创建了之后呢他就会
# 已经创建了之后呢他就会可以
# 已经创建了之后呢他就会可以告诉你
# 已经创建了之后呢他就会可以告诉你去
# 已经创建了之后呢他就会可以告诉你去转到
# 相关
# 相关的
# 相关的资源
# 相关的资源里面
# 相关的资源里面那大
# 相关的资源里面那大家
# 相关的资源里面那大家可以看
# 得到
# 得到哦
# 得到哦在这里
# 得到哦在这里面
# 得到哦在这里面的话
# 得到哦在这里面的话他
# 得到哦在这里面的话他已经
# 得到哦在这里面的话他已经把
# 得到哦在这里面的话他已经把你
# 得到哦在这里面的话他已经把你需要的
# 得到哦在这里面的话他已经把你需要的资源
# 组
# 组已经
# 组已经绑定
# 组已经绑定了
# 组已经绑定了当然
# 组已经绑定了当然也
# 组已经绑定了当然也在
# 组已经绑定了当然也在存储
# 组已经绑定了当然也在存储的
# 组已经绑定了当然也在存储的空间
# 还有
# 还有位置
# 还有位置上面
# 还有位置上面都
# 还有位置上面都做了
# 还有位置上面都做了一些
# 还有位置上面都做了一些绑定
# 还有位置上面都做了一些绑定啊
# 还有位置上面都做了一些绑定啊在这里
# 面
# 面你
# 面你就可以
# 面你就可以直接
# 面你就可以直接的
# 面你就可以直接的去
# 面你就可以直接的去使用
# 面你就可以直接的去使用你的
# 面你就可以直接的去使用你的azure
# 面你就可以直接的去使用你的azuremachine
# learning
# learning的一个
# learning的一个平台
# learning的一个平台在这
# learning的一个平台在这上面
# learning的一个平台在这上面的话
# learning的一个平台在这上面的话啊
# 我们
# 我们可以
# 我们可以根据
# 我们可以根据呃
# 我们可以根据呃情况
# 我们可以根据呃情况呢
# 我们可以根据呃情况呢去
# 我们可以根据呃情况呢去点击
# 我们可以根据呃情况呢去点击啊
# 啊
# 啊这个
# 啊这个工作室
# 啊这个工作室里面的
# 啊这个工作室里面的url
# 啊这个工作室里面的url啊
# 去
# 去跳转
# 去跳转到
# 去跳转到我们的
# 去跳转到我们的azure
# 去跳转到我们的azure机器
# 去跳转到我们的azure机器服务
# 的一个
# 的一个呃
# 的一个呃相关
# 的一个呃相关的一个
# 的一个呃相关的一个连接
# 的一个呃相关的一个连接那
# 的一个呃相关的一个连接那这个
# 时候
# 时候你
# 时候你就可以
# 时候你就可以根据
# 时候你就可以根据你的
# 时候你就可以根据你的需要
# 时候你就可以根据你的需要去
# 时候你就可以根据你的需要去创建
# 时候你就可以根据你的需要去创建爱你
# 时候你就可以根据你的需要去创建爱你的
# 呃
# 呃一些
# 呃一些公
# 呃一些公呃
# 呃一些公呃跟
# 呃一些公呃跟机器学习
# 呃一些公呃跟机器学习相关
# 呃一些公呃跟机器学习相关的
# 呃一些公呃跟机器学习相关的一些
# 工作
# 工作举个例子
# 工作举个例子呃
# 工作举个例子呃我们
# 工作举个例子呃我们做
# 工作举个例子呃我们做机器学习
# 工作举个例子呃我们做机器学习可能
# 工作举个例子呃我们做机器学习可能需要
# 到
# 到logo
# 到logo那你
# 到logo那你这个
# 到logo那你这个时候
# 到logo那你这个时候你
# 到logo那你这个时候你可能
# 到logo那你这个时候你可能是要
# 到logo那你这个时候你可能是要去
# 到logo那你这个时候你可能是要去呃
# 做
# 做logo
# 做logo的
# 做logo的操作
# 做logo的操作啊
# 做logo的操作啊在这里
# 做logo的操作啊在这里面
# 做logo的操作啊在这里面你
# 做logo的操作啊在这里面你可以去
# 添加
# 添加啊
# 添加啊新的
# 添加啊新的logo
# 添加啊新的logo也可以
# 添加啊新的logo也可以呢
# 添加啊新的logo也可以呢呃
# 去
# 去在
# 去在sample
# 去在sample里面
# 去在sample里面因为你
# 去在sample里面因为你是要
# 去在sample里面因为你是要去
# 去在sample里面因为你是要去学习
# 去在sample里面因为你是要去学习那你
# 去在sample里面因为你是要去学习那你可以在
# 上面
# 上面去
# 上面去呃
# 上面去呃学习
# 上面去呃学习一个
# 上面去呃学习一个呃
# 上面去呃学习一个呃添加
# 一个
# 一个呃
# 一个呃相关
# 一个呃相关的一个
# 一个呃相关的一个怎么样
# 一个呃相关的一个怎么样子
# 一个呃相关的一个怎么样子去
# 用
# 用ml
# 用mlexperiment
# 用mlexperiment的
# 用mlexperiment的操作
# 用mlexperiment的操作那
# 用mlexperiment的操作那这个
# 用mlexperiment的操作那这个时候
# 用mlexperiment的操作那这个时候呢
# 你
# 你可以去
# 你可以去x
# 你可以去xsample
# 你可以去xsample的一个
# 你可以去xsample的一个文件夹
# 你可以去xsample的一个文件夹里面
# 你可以去xsample的一个文件夹里面啊
# 你可以去xsample的一个文件夹里面啊去
# 把它
# 把它克隆
# 把它克隆到
# 把它克隆到你的
# 把它克隆到你的本地
# 把它克隆到你的本地上面
# 把它克隆到你的本地上面像
# 把它克隆到你的本地上面像举个例子
# 把它克隆到你的本地上面像举个例子我在
# 这里
# 这里是一个
# 这里是一个looking
# 这里是一个looking费
# 这里是一个looking费的一个
# 这里是一个looking费的一个目录
# 这里是一个looking费的一个目录啊
# 是我
# 是我的
# 是我的名字
# 是我的名字然后
# 是我的名字然后就
# 是我的名字然后就克隆
# 是我的名字然后就克隆他
# 是我的名字然后就克隆他就可以
# 把
# 把呃
# 把呃sample
# 把呃sample里面的
# 把呃sample里面的文件
# 把呃sample里面的文件呃
# 把呃sample里面的文件呃克隆
# 把呃sample里面的文件呃克隆道理
# 把呃sample里面的文件呃克隆道理的
# 把呃sample里面的文件呃克隆道理的呃
# 一个
# 一个目录
# 一个目录上面
# 一个目录上面然后
# 一个目录上面然后呢
# 一个目录上面然后呢在这
# 一个目录上面然后呢在这下面
# 一个目录上面然后呢在这下面的话
# 一个目录上面然后呢在这下面的话好像
# 说我
# 说我要去
# 说我要去呃
# 说我要去呃乱
# 说我要去呃乱我的
# 说我要去呃乱我的一个
# 说我要去呃乱我的一个sdk
# 说我要去呃乱我的一个sdka
# m
# ml
# ml的
# ml的sdk
# ml的sdk那我
# ml的sdk那我点击
# ml的sdk那我点击他的
# 文件
# 文件的
# 文件的时候
# 文件的时候大家
# 文件的时候大家可以
# 文件的时候大家可以发现
# 文件的时候大家可以发现啊
# 文件的时候大家可以发现啊他的
# 文件的时候大家可以发现啊他的ml
# 啊
# 啊都是
# 啊都是英文
# 啊都是英文比较
# 啊都是英文比较高大
# 啊都是英文比较高大上
# 啊都是英文比较高大上但是不
# 啊都是英文比较高大上但是不怕
# 啊
# 啊啊
# 啊啊在
# 啊啊在上面
# 啊啊在上面的话
# 啊啊在上面的话呢
# 啊啊在上面的话呢呃
# 啊啊在上面的话呢呃都是
# 啊啊在上面的话呢呃都是一些
# 怎么样
# 怎么样子
# 怎么样子去
# 怎么样子去呃
# 怎么样子去呃利用
# 怎么样子去呃利用嗯
# 怎么样子去呃利用嗯这个
# azure
# azuremachine
# azuremachinelearning
# azuremachinelearning去
# azuremachinelearning去做一些
# azuremachinelearning去做一些模型
# azuremachinelearning去做一些模型训练
# azuremachinelearning去做一些模型训练的
# 那
# 那这个
# 那这个时候
# 那这个时候大家
# 那这个时候大家知道
# 那这个时候大家知道你
# 那这个时候大家知道你需要
# 那这个时候大家知道你需要去
# 那这个时候大家知道你需要去做一些
# 那这个时候大家知道你需要去做一些相关
# 的
# 的一些
# 的一些算
# 的一些算力
# 的一些算力呃
# 的一些算力呃那你
# 的一些算力呃那你这个
# 的一些算力呃那你这个收
# 了
# 了他
# 了他会
# 了他会告诉你
# 了他会告诉你你
# 了他会告诉你你没有
# 了他会告诉你你没有去
# 了他会告诉你你没有去做
# 了他会告诉你你没有去做算
# 了他会告诉你你没有去做算力
# 了他会告诉你你没有去做算力怎么办
# 了他会告诉你你没有去做算力怎么办呢
# 了他会告诉你你没有去做算力怎么办呢你
# 了他会告诉你你没有去做算力怎么办呢你要去
# 选择
# 选择一个
# 选择一个呃
# 选择一个呃新的
# 选择一个呃新的一个
# 选择一个呃新的一个compute
# 选择一个呃新的一个compute啊
# 选择一个呃新的一个compute啊啊
# 在这里
# 在这里面
# 在这里面你
# 在这里面你可以
# 在这里面你可以选择
# 在这里面你可以选择的
# 在这里面你可以选择的是
# 在这里面你可以选择的是gpu
# 在这里面你可以选择的是gpu跟
# 在这里面你可以选择的是gpu跟cpu
# 的
# 的computer
# 的computer因为
# 的computer因为我在
# 的computer因为我在这里
# 的computer因为我在这里的话
# 的computer因为我在这里的话啊
# 的computer因为我在这里的话啊是
# 呃
# 呃有
# 呃有你
# 呃有你可以用
# 呃有你可以用一个
# 呃有你可以用一个叫做
# 呃有你可以用一个叫做m
# 选择
# 选择gpu
# 选择gpu的
# 选择gpu的时候
# 选择gpu的时候你
# 选择gpu的时候你可以
# 选择gpu的时候你可以选择
# 选择gpu的时候你可以选择的
# 选择gpu的时候你可以选择的是
# 选择gpu的时候你可以选择的是呃
# 选择gpu的时候你可以选择的是呃一个
# m
# m六零
# m六零的一个
# m六零的一个gpu
# m六零的一个gpu的一个
# m六零的一个gpu的一个算
# m六零的一个gpu的一个算力
# m六零的一个gpu的一个算力当然
# m六零的一个gpu的一个算力当然你
# 如果
# 如果是
# 如果是节省
# 如果是节省一点
# 如果是节省一点的话
# 如果是节省一点的话因为你
# 如果是节省一点的话因为你有
# 如果是节省一点的话因为你有学生
# 账号
# 账号啊
# 账号啊有一
# 账号啊有一百
# 账号啊有一百刀
# 账号啊有一百刀的一个
# 账号啊有一百刀的一个呃
# 账号啊有一百刀的一个呃算
# 账号啊有一百刀的一个呃算力
# 的一个
# 的一个支持
# 的一个支持那
# 的一个支持那这个
# 的一个支持那这个时候
# 的一个支持那这个时候呢
# 的一个支持那这个时候呢你
# 的一个支持那这个时候呢你可以
# 的一个支持那这个时候呢你可以选择
# 的一个支持那这个时候呢你可以选择啊
# 的一个支持那这个时候呢你可以选择啊一个
# gpu
# gpu啊
# gpu啊啊
# gpu啊啊每个
# gpu啊啊每个小时
# gpu啊啊每个小时来
# gpu啊啊每个小时来算
# gpu啊啊每个小时来算就
# gpu啊啊每个小时来算就一点五
# 八
# 八美金
# 八美金啊
# 八美金啊一点
# 八美金啊一点五百
# 八美金啊一点五百五五
# 八美金啊一点五百五五八
# 八美金啊一点五百五五八刀
# 啊
# 啊啊
# 啊啊的一个
# 啊啊的一个算
# 啊啊的一个算力
# 啊啊的一个算力啊
# 啊啊的一个算力啊所以
# 啊啊的一个算力啊所以在这里
# 啊啊的一个算力啊所以在这里面
# 啊啊的一个算力啊所以在这里面的话
# 啊
# 啊你
# 啊你可以
# 啊你可以根据
# 啊你可以根据你的
# 啊你可以根据你的需要
# 啊你可以根据你的需要去
# 啊你可以根据你的需要去做
# 啊你可以根据你的需要去做而且
# 啊你可以根据你的需要去做而且这个
# 呢
# 呢你不
# 呢你不用的
# 呢你不用的时候
# 呢你不用的时候把它
# 呢你不用的时候把它停
# 呢你不用的时候把它停掉
# 呢你不用的时候把它停掉它是
# 呢你不用的时候把它停掉它是不算
# 呢你不用的时候把它停掉它是不算任何
# 呢你不用的时候把它停掉它是不算任何费用
# 的
# 的所以
# 的所以呢
# 的所以呢你
# 的所以呢你要
# 的所以呢你要看
# 的所以呢你要看你
# 的所以呢你要看你自己的
# 的所以呢你要看你自己的实际情况
# 的所以呢你要看你自己的实际情况当然
# 的所以呢你要看你自己的实际情况当然你
# 可以用
# 可以用cpu
# 可以用cpucpu
# 可以用cpucpu的话
# 可以用cpucpu的话呢
# 可以用cpucpu的话呢它
# 可以用cpucpu的话呢它有很多
# 可以用cpucpu的话呢它有很多的
# 可以用cpucpu的话呢它有很多的cu
# 的
# 的呃
# 的呃算
# 的呃算力
# 的呃算力在
# 的呃算力在上面
# 的呃算力在上面像
# 的呃算力在上面像我在
# 的呃算力在上面像我在这里
# 的呃算力在上面像我在这里的话
# 的呃算力在上面像我在这里的话我就
# 用
# 用了一
# 用了一个
# 用了一个叫做
# 用了一个叫做ds
# 用了一个叫做ds三
# 用了一个叫做ds三v
# 用了一个叫做ds三v二
# 用了一个叫做ds三v二的
# 用了一个叫做ds三v二的一个
# 用了一个叫做ds三v二的一个呃
# 用了一个叫做ds三v二的一个呃普通
# 的一个
# 的一个cpu
# 的一个cpu它是
# 的一个cpu它是零点
# 的一个cpu它是零点一四
# 的一个cpu它是零点一四刀
# 的一个cpu它是零点一四刀啊
# 呃
# 呃四一
# 呃四一刀
# 呃四一刀啊
# 呃四一刀啊啊
# 呃四一刀啊啊作为
# 呃四一刀啊啊作为每个
# 呃四一刀啊啊作为每个小时
# 的
# 的算
# 的算力
# 的算力那我
# 的算力那我就在
# 的算力那我就在这里
# 的算力那我就在这里创建
# 的算力那我就在这里创建创建
# 的算力那我就在这里创建创建也是
# 的算力那我就在这里创建创建也是虚实
# 呃
# 呃去
# 呃去创建
# 呃去创建啊
# 呃去创建啊呃
# 呃去创建啊呃它
# 会
# 会创建
# 会创建成功之后
# 会创建成功之后就会
# 会创建成功之后就会告诉你
# 会创建成功之后就会告诉你哦
# 会创建成功之后就会告诉你哦这个
# 会创建成功之后就会告诉你哦这个东西
# 会创建成功之后就会告诉你哦这个东西是
# 会创建成功之后就会告诉你哦这个东西是怎么样
# 子
# 子的
# 子的嗯
# 子的嗯大家
# 子的嗯大家可以看
# 子的嗯大家可以看得到
# 子的嗯大家可以看得到哈
# 哦你
# 哦你的
# 哦你的算
# 哦你的算力
# 哦你的算力也不
# 哦你的算力也不需要
# 哦你的算力也不需要去
# 哦你的算力也不需要去投入
# 哦你的算力也不需要去投入啊
# 痒
# 痒而且
# 痒而且呢
# 痒而且呢你
# 痒而且呢你可以去
# 痒而且呢你可以去呃
# 痒而且呢你可以去呃做
# 痒而且呢你可以去呃做很多
# 的
# 的一些
# 的一些机器学习
# 的一些机器学习相关
# 的一些机器学习相关的
# 的一些机器学习相关的工作
# 的一些机器学习相关的工作另外
# 的一些机器学习相关的工作另外呢
# 的一些机器学习相关的工作另外呢在这里
# 面
# 面我想
# 面我想介绍
# 面我想介绍给
# 面我想介绍给大家
# 面我想介绍给大家一个
# 面我想介绍给大家一个非常
# 面我想介绍给大家一个非常好玩
# 面我想介绍给大家一个非常好玩的
# 东西
# 东西就是
# 东西就是他的
# 东西就是他的比赛
# 东西就是他的比赛呢
# 东西就是他的比赛呢我们在
# 东西就是他的比赛呢我们在等待
# 东西就是他的比赛呢我们在等待计算
# 嗯
# 嗯的
# 嗯的这个
# 嗯的这个算
# 嗯的这个算力
# 嗯的这个算力呃
# 嗯的这个算力呃创
# 嗯的这个算力呃创启动
# 起来
# 起来的
# 起来的时候
# 起来的时候呢
# 起来的时候呢你
# 起来的时候呢你就可以
# 起来的时候呢你就可以去
# 起来的时候呢你就可以去看一下
# 起来的时候呢你就可以去看一下这个
# 起来的时候呢你就可以去看一下这个比赛
# 起来的时候呢你就可以去看一下这个比赛了
# 这个
# 这个第三
# 这个第三呢
# 这个第三呢是什么
# 这个第三呢是什么东西
# 这个第三呢是什么东西呢
# 这个第三呢是什么东西呢大家
# 这个第三呢是什么东西呢大家知道
# 这个第三呢是什么东西呢大家知道在
# windows
# windows上面
# windows上面嗯
# windows上面嗯我们
# windows上面嗯我们可以
# windows上面嗯我们可以很简单
# windows上面嗯我们可以很简单的
# 去
# 去拖拽
# 去拖拽一些
# 去拖拽一些控件
# 去拖拽一些控件去
# 去拖拽一些控件去完成
# 去拖拽一些控件去完成一些
# 去拖拽一些控件去完成一些windows
# 的
# 的界面
# 的界面啊
# 的界面啊在这里
# 的界面啊在这里面
# 的界面啊在这里面的话
# 的界面啊在这里面的话呢
# 的界面啊在这里面的话呢你
# 的界面啊在这里面的话呢你可以
# 通过
# 通过啊
# 通过啊相关
# 通过啊相关的
# 通过啊相关的呃
# 通过啊相关的呃一个
# 呃
# 呃拖拽
# 呃拖拽呃
# 呃拖拽呃去
# 呃拖拽呃去完成
# 呃拖拽呃去完成机器学习
# 呃拖拽呃去完成机器学习里面
# 呃拖拽呃去完成机器学习里面相关
# 的
# 的一些
# 的一些知识
# 的一些知识的
# 的一些知识的一些
# 的一些知识的一些创建
# 的一些知识的一些创建像
# 的一些知识的一些创建像我在
# 的一些知识的一些创建像我在这里
# 的一些知识的一些创建像我在这里的话
# 的一些知识的一些创建像我在这里的话大家
# 可以看
# 可以看到
# 可以看到我
# 可以看到我我
# 可以看到我我选择
# 可以看到我我选择了一
# 可以看到我我选择了一个
# 可以看到我我选择了一个图像识别
# 可以看到我我选择了一个图像识别的
# 可以看到我我选择了一个图像识别的操作
# 之后
# 之后呢
# 之后呢呃
# 之后呢呃如果你
# 之后呢呃如果你选择
# 之后呢呃如果你选择这个
# 之后呢呃如果你选择这个比赛
# 之后呢呃如果你选择这个比赛呢
# 之后呢呃如果你选择这个比赛呢你
# 之后呢呃如果你选择这个比赛呢你可以看
# 到
# 到它
# 到它从
# 到它从图
# 到它从图图像
# 到它从图图像急
# 到它从图图像急啊
# 到它从图图像急啊到
# 到它从图图像急啊到图像
# 到它从图图像急啊到图像的
# 一些
# 一些转变
# 一些转变到
# 一些转变到图像
# 一些转变到图像图片
# 一些转变到图像图片的
# 一些转变到图像图片的一些
# 一些转变到图像图片的一些分类
# 一些转变到图像图片的一些分类哎
# 一些转变到图像图片的一些分类哎到
# 训练
# 训练都是
# 训练都是通过
# 训练都是通过拖拽
# 训练都是通过拖拽去
# 训练都是通过拖拽去完成
# 训练都是通过拖拽去完成的
# 训练都是通过拖拽去完成的这样子
# 的话
# 的话呢
# 的话呢他
# 的话呢他就让
# 的话呢他就让机器学习
# 的话呢他就让机器学习更加
# 的话呢他就让机器学习更加的
# 的话呢他就让机器学习更加的呃
# 自动化
# 自动化啊
# 自动化啊可是
# 自动化啊可是话
# 自动化啊可是话啊
# 自动化啊可是话啊啊
# 自动化啊可是话啊啊所以
# 呢
# 呢呃
# 呢呃通过
# 呢呃通过azure
# 呢呃通过azure的
# 呢呃通过azure的机器学习
# 呢呃通过azure的机器学习服务
# 呢呃通过azure的机器学习服务了
# 呢呃通过azure的机器学习服务了你
# 呢呃通过azure的机器学习服务了你可以
# 呢呃通过azure的机器学习服务了你可以呃
# 呢呃通过azure的机器学习服务了你可以呃通过
# 设计器
# 设计器去
# 设计器去完成
# 设计器去完成你的
# 设计器去完成你的机器学习
# 设计器去完成你的机器学习的
# 设计器去完成你的机器学习的步骤
# 另外
# 另外的
# 另外的也
# 另外的也还可以
# 另外的也还可以用
# 另外的也还可以用业界
# 另外的也还可以用业界最受欢迎
# 的
# 的auto
# 的automl
# 的automl去
# 的automl去完成
# 的automl去完成相关
# 的automl去完成相关的
# 的automl去完成相关的任务
# 也是
# 也是非常
# 也是非常方便
# 也是非常方便可用
# 也是非常方便可用的
# 也是非常方便可用的然后
# 也是非常方便可用的然后我们
# 也是非常方便可用的然后我们回到
# 我们的
# 我们的logo
# 我们的logo去
# 我们的logo去看一下
# 我们的logo去看一下他是
# 我们的logo去看一下他是不是
# 我们的logo去看一下他是不是已经
# 我们的logo去看一下他是不是已经创建
# 我们的logo去看一下他是不是已经创建完了
# 好
# 好当我们
# 好当我们的
# 好当我们的算
# 力
# 力创建
# 力创建完
# 力创建完之后
# 力创建完之后啊
# 力创建完之后啊大家
# 力创建完之后啊大家可以看
# 力创建完之后啊大家可以看得到
# 力创建完之后啊大家可以看得到他
# 力创建完之后啊大家可以看得到他会去
# 提醒
# 提醒你
# 提醒你哦
# 提醒你哦这个
# 提醒你哦这个算
# 提醒你哦这个算力
# 提醒你哦这个算力已经
# 提醒你哦这个算力已经创建
# 提醒你哦这个算力已经创建成功
# 提醒你哦这个算力已经创建成功了然
# 提醒你哦这个算力已经创建成功了然后
# 在这
# 在这个时
# 在这个时候
# 在这个时候呢
# 在这个时候呢呃
# 在这个时候呢呃大家
# 在这个时候呢呃大家会
# 在这个时候呢呃大家会担心
# 在这个时候呢呃大家会担心的
# 在这个时候呢呃大家会担心的是
# 哎呀我
# 哎呀我这个
# 哎呀我这个算
# 哎呀我这个算力
# 哎呀我这个算力究竟是
# 哎呀我这个算力究竟是用
# 哎呀我这个算力究竟是用三
# 哎呀我这个算力究竟是用三者
# 哎呀我这个算力究竟是用三者环境
# 哎呀我这个算力究竟是用三者环境举个例子
# 哎呀我这个算力究竟是用三者环境举个例子你
# 可以
# 可以用的
# 可以用的是
# 可以用的是python
# 可以用的是python三点
# 可以用的是python三点六
# 可以用的是python三点六的
# 环境
# 环境当然
# 环境当然也可以
# 环境当然也可以用
# 环境当然也可以用三点
# 环境当然也可以用三点八
# 环境当然也可以用三点八啊
# 环境当然也可以用三点八啊还有
# 环境当然也可以用三点八啊还有另外的
# 它
# 它也
# 它也支持
# 它也支持r
# 它也支持r的
# 它也支持r的这种
# 它也支持r的这种算
# 它也支持r的这种算力
# 它也支持r的这种算力的一个
# 它也支持r的这种算力的一个支持
# 它也支持r的这种算力的一个支持所以
# 呢
# 呢在这里
# 呢在这里面
# 呢在这里面呢
# 呢在这里面呢是非
# 呢在这里面呢是非常
# 呢在这里面呢是非常方便
# 呢在这里面呢是非常方便的
# 呢在这里面呢是非常方便的啊
# 呢在这里面呢是非常方便的啊而且
# 你
# 你可以
# 你可以通过
# 你可以通过呃
# 你可以通过呃logo
# 你可以通过呃logo的
# 你可以通过呃logo的去
# 你可以通过呃logo的去线上
# 你可以通过呃logo的去线上的
# 这个
# 这个logo
# 这个logo呢
# 这个logo呢去
# 这个logo呢去添加
# 这个logo呢去添加代码
# 这个logo呢去添加代码然后
# 这个logo呢去添加代码然后运行
# 这个logo呢去添加代码然后运行所以
# 这个logo呢去添加代码然后运行所以呢
# 通过
# 通过azure
# 通过azuremachine
# 通过azuremachinelearning
# 通过azuremachinelearning的
# 通过azuremachinelearning的服务
# 通过azuremachinelearning的服务呢
# 通过azuremachinelearning的服务呢呃
# 可以
# 可以让你
# 可以让你的
# 可以让你的机器学习
# 可以让你的机器学习了
# 可以让你的机器学习了呃
# 可以让你的机器学习了呃呃
# 可以让你的机器学习了呃呃学习
# 或者
# 或者实验
# 或者实验的
# 或者实验的环境
# 或者实验的环境呢
# 或者实验的环境呢得到
# 或者实验的环境呢得到一个
# 或者实验的环境呢得到一个提升
# 或者实验的环境呢得到一个提升而且
# 是在
# 是在呃
# 是在呃不用
# 是在呃不用付费
# 是在呃不用付费的
# 是在呃不用付费的前提
# 是在呃不用付费的前提下去
# 完成
# 完成这个
# 完成这个事
# 完成这个事啊
# 完成这个事啊希望
# 完成这个事啊希望各位
# 完成这个事啊希望各位同学
# 完成这个事啊希望各位同学了啊
# 完成这个事啊希望各位同学了啊马上
# 去
# 去尝试一下
# 去尝试一下啊
# 去尝试一下啊呃
# 去尝试一下啊呃通过
# 去尝试一下啊呃通过azure
# 去尝试一下啊呃通过azure的
# 机器学习
# 机器学习服务
# 机器学习服务去
# 机器学习服务去完成
# 机器学习服务去完成你的
# 机器学习服务去完成你的呃
# 机器学习服务去完成你的呃ai
# 机器学习服务去完成你的呃ai的
# 学习
# 学习啊
# 学习啊也可以
# 学习啊也可以作为
# 学习啊也可以作为学习
# 学习啊也可以作为学习的
# 学习啊也可以作为学习的环境
# 学习啊也可以作为学习的环境啊
# 谢谢
# 谢谢大家

# %%
transcriptions.append(srt.Subtitle(index, datetime.timedelta(0, wordstartsec, wordstartmicrosec), datetime.timedelta(0, wordstartsec+bin, 0), transcript))
subtitles = srt.compose(transcriptions)
print(subtitles)
with open("./srt/cn_subtitle.srt", "w", encoding="utf-8") as f:
    f.write(subtitles)
# Out:
# 1
# 00:00:03,000 --> 00:00:06,000
# 哦哦今天我想
#
# 2
# 00:00:06,000 --> 00:00:09,000
# 给各位同学来介绍一下azure机器学习
#
# 3
# 00:00:09,000 --> 00:00:12,000
# 的一个部分那如果大家呢
#
# 4
# 00:00:13,000 --> 00:00:16,000
# 呃有看上面的小视频呢大家会知道azure上面
#
# 5
# 00:00:16,000 --> 00:00:19,000
# 呢有非常呃强大的一些机器学习的
#
# 6
# 00:00:19,000 --> 00:00:22,000
# 一些功能啊啊我们呃之前
#
# 7
# 00:00:22,000 --> 00:00:25,000
# 呢就介绍过一个零代码的方式去做呃
#
# 8
# 00:00:25,000 --> 00:00:28,000
# 一个计算机视觉的任务那接下来呢我想
#
# 9
# 00:00:28,000 --> 00:00:31,000
# 给大家更专业的部分大家知道我们做
#
# 10
# 00:00:32,000 --> 00:00:35,000
# 机器学习的时候呢会遇到一个状况就是呃
#
# 11
# 00:00:35,000 --> 00:00:38,000
# 我们可能没有gpu或者是没有一些
#
# 12
# 00:00:38,000 --> 00:00:41,000
# 机器学习的平台还有搭建环境的时候非常
#
# 13
# 00:00:41,000 --> 00:00:44,000
# 不方便但是如果你通过azure了可以很快
#
# 14
# 00:00:44,000 --> 00:00:47,000
# 速地去完成相关的工作你可以不
#
# 15
# 00:00:48,000 --> 00:00:51,000
# 需要关注你的整个呃平台的一些
#
# 16
# 00:00:51,000 --> 00:00:54,000
# 搭建情况啊啊安装啊配置文件之类的
#
# 17
# 00:00:54,000 --> 00:00:57,000
# 就可以启动你的azure的一些机器学习上面的
#
# 18
# 00:00:57,000 --> 00:01:00,000
# 一些服务包括说logo包括说python的
#
# 19
# 00:01:01,000 --> 00:01:04,000
# 环境还有就是一些gpu的一些算力的
#
# 20
# 00:01:04,000 --> 00:01:07,000
# 一些呃使用在这里面的话呢我想给大家介绍一下
#
# 21
# 00:01:07,000 --> 00:01:10,000
# azure的整个呃机器学习的一个服务的一个
#
# 22
# 00:01:10,000 --> 00:01:13,000
# 平台好首先呢我们回到azure的portal
#
# 23
# 00:01:14,000 --> 00:01:17,000
# 里面在这个坡头里面呢呃会有很多的
#
# 24
# 00:01:17,000 --> 00:01:20,000
# 一些呃资资源的一些创建我们呢
#
# 25
# 00:01:20,000 --> 00:01:23,000
# 首先还是要去创建一个azure及关于机器
#
# 26
# 00:01:23,000 --> 00:01:26,000
# 服务的呃资源我们去选择ai
#
# 27
# 00:01:27,000 --> 00:01:30,000
# 加机器学习然后呢在这里面定义
#
# 28
# 00:01:30,000 --> 00:01:33,000
# 列呃里面的呃第一个就是我们
#
# 29
# 00:01:33,000 --> 00:01:36,000
# 的机器学习服务然后点击创建那这个
#
# 30
# 00:01:37,000 --> 00:01:40,000
# 收了他就会引导你去做一个azure的一个机器学习
#
# 31
# 00:01:41,000 --> 00:01:44,000
# 的一个创建在这里面的话你可以
#
# 32
# 00:01:44,000 --> 00:01:47,000
# 选择的是原有的资源组或者是自己
#
# 33
# 00:01:47,000 --> 00:01:50,000
# 可以新建一个另外的你可能是要去创建
#
# 34
# 00:01:51,000 --> 00:01:54,000
# 一个机器学习的一个名字呃像ldemo
#
# 35
# 00:01:54,000 --> 00:01:57,000
# 哦然后呢你
#
# 36
# 00:01:57,000 --> 00:02:00,000
# 可以选择你的区域然后你的存储的账户为什么要有
#
# 37
# 00:02:00,000 --> 00:02:03,000
# 存储呢因为呃在里面的话它可以帮你
#
# 38
# 00:02:03,000 --> 00:02:06,000
# 去保存你的呃朱比特的logo还有相关的
#
# 39
# 00:02:06,000 --> 00:02:09,000
# 一些呃关于数据的整理啊呃还有另外的
#
# 40
# 00:02:10,000 --> 00:02:13,000
# 一些相关的呃包括说训练的一些操作
#
# 41
# 00:02:13,000 --> 00:02:16,000
# 还有就是一些呃密钥啊啊
#
# 42
# 00:02:16,000 --> 00:02:19,000
# 这些都是一个非常有用的当然你需不需要去
#
# 43
# 00:02:19,000 --> 00:02:22,000
# 注册一个容器了啊也可以默认可以不
#
# 44
# 00:02:22,000 --> 00:02:25,000
# 用啊在这里我们先不用然后就开始
#
# 45
# 00:02:25,000 --> 00:02:28,000
# 去创建了那在创建
#
# 46
# 00:02:28,000 --> 00:02:31,000
# 的过程当中他会去也是做我们的验证的
#
# 47
# 00:02:33,000 --> 00:02:36,000
# 步骤稍等如果
#
# 48
# 00:02:36,000 --> 00:02:39,000
# 验证通过的话你就可以直接的去创建了当
#
# 49
# 00:02:39,000 --> 00:02:42,000
# 安妮的
#
# 50
# 00:02:42,000 --> 00:02:45,000
# 呃azuremachinelearning的服务了呃
#
# 51
# 00:02:46,000 --> 00:02:49,000
# 已经创建了之后呢他就会可以告诉你去转到
#
# 52
# 00:02:49,000 --> 00:02:52,000
# 相关的资源里面那大家可以看
#
# 53
# 00:02:52,000 --> 00:02:55,000
# 得到哦在这里面的话他已经把你需要的资源
#
# 54
# 00:02:55,000 --> 00:02:58,000
# 组已经绑定了当然也在存储的空间
#
# 55
# 00:02:58,000 --> 00:03:01,000
# 还有位置上面都做了一些绑定啊在这里
#
# 56
# 00:03:02,000 --> 00:03:05,000
# 面你就可以直接的去使用你的azuremachine
#
# 57
# 00:03:05,000 --> 00:03:08,000
# learning的一个平台在这上面的话啊
#
# 58
# 00:03:08,000 --> 00:03:11,000
# 我们可以根据呃情况呢去点击啊
#
# 59
# 00:03:11,000 --> 00:03:14,000
# 啊这个工作室里面的url啊
#
# 60
# 00:03:14,000 --> 00:03:17,000
# 去跳转到我们的azure机器服务
#
# 61
# 00:03:18,000 --> 00:03:21,000
# 的一个呃相关的一个连接那这个
#
# 62
# 00:03:21,000 --> 00:03:24,000
# 时候你就可以根据你的需要去创建爱你的
#
# 63
# 00:03:24,000 --> 00:03:27,000
# 呃一些公呃跟机器学习相关的一些
#
# 64
# 00:03:27,000 --> 00:03:30,000
# 工作举个例子呃我们做机器学习可能需要
#
# 65
# 00:03:31,000 --> 00:03:34,000
# 到logo那你这个时候你可能是要去呃
#
# 66
# 00:03:34,000 --> 00:03:37,000
# 做logo的操作啊在这里面你可以去
#
# 67
# 00:03:37,000 --> 00:03:40,000
# 添加啊新的logo也可以呢呃
#
# 68
# 00:03:40,000 --> 00:03:43,000
# 去在sample里面因为你是要去学习那你可以在
#
# 69
# 00:03:44,000 --> 00:03:47,000
# 上面去呃学习一个呃添加
#
# 70
# 00:03:47,000 --> 00:03:50,000
# 一个呃相关的一个怎么样子去
#
# 71
# 00:03:50,000 --> 00:03:53,000
# 用mlexperiment的操作那这个时候呢
#
# 72
# 00:03:53,000 --> 00:03:56,000
# 你可以去xsample的一个文件夹里面啊去
#
# 73
# 00:03:56,000 --> 00:03:59,000
# 把它克隆到你的本地上面像举个例子我在
#
# 74
# 00:04:00,000 --> 00:04:03,000
# 这里是一个looking费的一个目录啊
#
# 75
# 00:04:05,000 --> 00:04:08,000
# 是我的名字然后就克隆他就可以
#
# 76
# 00:04:08,000 --> 00:04:11,000
# 把呃sample里面的文件呃克隆道理的呃
#
# 77
# 00:04:11,000 --> 00:04:14,000
# 一个目录上面然后呢在这下面的话好像
#
# 78
# 00:04:14,000 --> 00:04:17,000
# 说我要去呃乱我的一个sdka
#
# 79
# 00:04:17,000 --> 00:04:20,000
# ml的sdk那我点击他的
#
# 80
# 00:04:20,000 --> 00:04:23,000
# 文件的时候大家可以发现啊他的ml
#
# 81
# 00:04:24,000 --> 00:04:27,000
# 啊都是英文比较高大上但是不怕
#
# 82
# 00:04:27,000 --> 00:04:30,000
# 啊啊在上面的话呢呃都是一些
#
# 83
# 00:04:30,000 --> 00:04:33,000
# 怎么样子去呃利用嗯这个
#
# 84
# 00:04:33,000 --> 00:04:36,000
# azuremachinelearning去做一些模型训练的
#
# 85
# 00:04:36,000 --> 00:04:39,000
# 那这个时候大家知道你需要去做一些相关
#
# 86
# 00:04:39,000 --> 00:04:42,000
# 的一些算力呃那你这个收
#
# 87
# 00:04:42,000 --> 00:04:45,000
# 了他会告诉你你没有去做算力怎么办呢你要去
#
# 88
# 00:04:45,000 --> 00:04:48,000
# 选择一个呃新的一个compute啊啊
#
# 89
# 00:04:48,000 --> 00:04:51,000
# 在这里面你可以选择的是gpu跟cpu
#
# 90
# 00:04:52,000 --> 00:04:55,000
# 的computer因为我在这里的话啊是
#
# 91
# 00:04:55,000 --> 00:04:58,000
# 呃有你可以用一个叫做m
#
# 92
# 00:04:58,000 --> 00:05:01,000
# 选择gpu的时候你可以选择的是呃一个
#
# 93
# 00:05:01,000 --> 00:05:04,000
# m六零的一个gpu的一个算力当然你
#
# 94
# 00:05:04,000 --> 00:05:07,000
# 如果是节省一点的话因为你有学生
#
# 95
# 00:05:08,000 --> 00:05:11,000
# 账号啊有一百刀的一个呃算力
#
# 96
# 00:05:11,000 --> 00:05:14,000
# 的一个支持那这个时候呢你可以选择啊一个
#
# 97
# 00:05:14,000 --> 00:05:17,000
# gpu啊啊每个小时来算就一点五
#
# 98
# 00:05:18,000 --> 00:05:21,000
# 八美金啊一点五百五五八刀
#
# 99
# 00:05:21,000 --> 00:05:24,000
# 啊啊的一个算力啊所以在这里面的话
#
# 100
# 00:05:24,000 --> 00:05:27,000
# 啊你可以根据你的需要去做而且这个
#
# 101
# 00:05:27,000 --> 00:05:30,000
# 呢你不用的时候把它停掉它是不算任何费用
#
# 102
# 00:05:31,000 --> 00:05:34,000
# 的所以呢你要看你自己的实际情况当然你
#
# 103
# 00:05:34,000 --> 00:05:37,000
# 可以用cpucpu的话呢它有很多的cu
#
# 104
# 00:05:37,000 --> 00:05:40,000
# 的呃算力在上面像我在这里的话我就
#
# 105
# 00:05:40,000 --> 00:05:43,000
# 用了一个叫做ds三v二的一个呃普通
#
# 106
# 00:05:43,000 --> 00:05:46,000
# 的一个cpu它是零点一四刀啊
#
# 107
# 00:05:46,000 --> 00:05:49,000
# 呃四一刀啊啊作为每个小时
#
# 108
# 00:05:50,000 --> 00:05:53,000
# 的算力那我就在这里创建创建也是虚实
#
# 109
# 00:05:53,000 --> 00:05:56,000
# 呃去创建啊呃它
#
# 110
# 00:05:57,000 --> 00:06:00,000
# 会创建成功之后就会告诉你哦这个东西是怎么样
#
# 111
# 00:06:00,000 --> 00:06:03,000
# 子的嗯大家可以看得到哈
#
# 112
# 00:06:03,000 --> 00:06:06,000
# 哦你的算力也不需要去投入啊
#
# 113
# 00:06:06,000 --> 00:06:09,000
# 痒而且呢你可以去呃做很多
#
# 114
# 00:06:09,000 --> 00:06:12,000
# 的一些机器学习相关的工作另外呢在这里
#
# 115
# 00:06:12,000 --> 00:06:15,000
# 面我想介绍给大家一个非常好玩的
#
# 116
# 00:06:16,000 --> 00:06:19,000
# 东西就是他的比赛呢我们在等待计算
#
# 117
# 00:06:19,000 --> 00:06:22,000
# 嗯的这个算力呃创启动
#
# 118
# 00:06:23,000 --> 00:06:26,000
# 起来的时候呢你就可以去看一下这个比赛了
#
# 119
# 00:06:26,000 --> 00:06:29,000
# 这个第三呢是什么东西呢大家知道在
#
# 120
# 00:06:29,000 --> 00:06:32,000
# windows上面嗯我们可以很简单的
#
# 121
# 00:06:33,000 --> 00:06:36,000
# 去拖拽一些控件去完成一些windows
#
# 122
# 00:06:36,000 --> 00:06:39,000
# 的界面啊在这里面的话呢你可以
#
# 123
# 00:06:39,000 --> 00:06:42,000
# 通过啊相关的呃一个
#
# 124
# 00:06:43,000 --> 00:06:46,000
# 呃拖拽呃去完成机器学习里面相关
#
# 125
# 00:06:46,000 --> 00:06:49,000
# 的一些知识的一些创建像我在这里的话大家
#
# 126
# 00:06:50,000 --> 00:06:53,000
# 可以看到我我选择了一个图像识别的操作
#
# 127
# 00:06:53,000 --> 00:06:56,000
# 之后呢呃如果你选择这个比赛呢你可以看
#
# 128
# 00:06:56,000 --> 00:06:59,000
# 到它从图图像急啊到图像的
#
# 129
# 00:07:00,000 --> 00:07:03,000
# 一些转变到图像图片的一些分类哎到
#
# 130
# 00:07:03,000 --> 00:07:06,000
# 训练都是通过拖拽去完成的这样子
#
# 131
# 00:07:06,000 --> 00:07:09,000
# 的话呢他就让机器学习更加的呃
#
# 132
# 00:07:10,000 --> 00:07:13,000
# 自动化啊可是话啊啊所以
#
# 133
# 00:07:13,000 --> 00:07:16,000
# 呢呃通过azure的机器学习服务了你可以呃通过
#
# 134
# 00:07:16,000 --> 00:07:19,000
# 设计器去完成你的机器学习的步骤
#
# 135
# 00:07:20,000 --> 00:07:23,000
# 另外的也还可以用业界最受欢迎
#
# 136
# 00:07:23,000 --> 00:07:26,000
# 的automl去完成相关的任务
#
# 137
# 00:07:26,000 --> 00:07:29,000
# 也是非常方便可用的然后我们回到
#
# 138
# 00:07:29,000 --> 00:07:32,000
# 我们的logo去看一下他是不是已经创建完了
#
# 139
# 00:07:33,000 --> 00:07:36,000
# 好当我们的算
#
# 140
# 00:07:36,000 --> 00:07:39,000
# 力创建完之后啊大家可以看得到他会去
#
# 141
# 00:07:39,000 --> 00:07:42,000
# 提醒你哦这个算力已经创建成功了然后
#
# 142
# 00:07:42,000 --> 00:07:45,000
# 在这个时候呢呃大家会担心的是
#
# 143
# 00:07:46,000 --> 00:07:49,000
# 哎呀我这个算力究竟是用三者环境举个例子你
#
# 144
# 00:07:49,000 --> 00:07:52,000
# 可以用的是python三点六的
#
# 145
# 00:07:52,000 --> 00:07:55,000
# 环境当然也可以用三点八啊还有另外的
#
# 146
# 00:07:55,000 --> 00:07:58,000
# 它也支持r的这种算力的一个支持所以
#
# 147
# 00:07:59,000 --> 00:08:02,000
# 呢在这里面呢是非常方便的啊而且
#
# 148
# 00:08:02,000 --> 00:08:05,000
# 你可以通过呃logo的去线上的
#
# 149
# 00:08:05,000 --> 00:08:08,000
# 这个logo呢去添加代码然后运行所以呢
#
# 150
# 00:08:08,000 --> 00:08:11,000
# 通过azuremachinelearning的服务呢呃
#
# 151
# 00:08:11,000 --> 00:08:14,000
# 可以让你的机器学习了呃呃学习
#
# 152
# 00:08:15,000 --> 00:08:18,000
# 或者实验的环境呢得到一个提升而且
#
# 153
# 00:08:18,000 --> 00:08:21,000
# 是在呃不用付费的前提下去
#
# 154
# 00:08:21,000 --> 00:08:24,000
# 完成这个事啊希望各位同学了啊马上
#
# 155
# 00:08:24,000 --> 00:08:27,000
# 去尝试一下啊呃通过azure的
#
# 156
# 00:08:28,000 --> 00:08:31,000
# 机器学习服务去完成你的呃ai的
#
# 157
# 00:08:31,000 --> 00:08:34,000
# 学习啊也可以作为学习的环境啊
#
# 158
# 00:08:32,000 --> 00:08:35,000
# 谢谢大家

# %%
strContent = ''
for speech in all_results:
    strContent += speech 

print(strContent)
# Out:
# 哦哦今天我想给各位同学来介绍一下Azure机器学习的一个部分。那如果大家呢，呃，有看上面的小视频呢？大家会知道，Azure上面呢，有非常呃，强大的一些机器学习的一些功能啊啊。我们，呃，之前呢就介绍过一个零代码的方式去做。呃，一个计算机视觉的任务，那接下来呢？我想给大家更专业的部分，大家知道我们做机器学习的时候呢，会遇到一个状况，就是，呃，我们可能没有GPU。或者是没有一些机器学习的平台，还有搭建环境的时候非常不方便。但是如果你通过Azure了，可以很快速的去完成相关的工作，你可以不需要关注你的整个。呃，平台的一些搭建情况啊啊，安装啊，配置文件之类的就可以启动你的Azure的一些机器学习上面的一些服务，包括说logo，包括说Python的环境，还有就是一些GPU的一些算力的一些呃，使用在这里面的话呢，我想给大家介绍一下。Azure的整个，呃，机器学习的一个服务的一个平台好。首先呢，我们回到Azure的portal里面，在这个坡头里面呢？呃，会有很多的一些呃资资源的一些创建，我们呢，首先还是要去创建一个Azure，去关于机器服务的，呃，资源，我们去选择AI加机器学习，然后呢在这里面定义列，呃，里面的。呃，第一个就是我们的机器学习服务，然后点击创建，那这个收了它就会引导你去做一个Azure的一个机器学习的一个。创建在这里面的话，你可以选择的是原有的资源组或者是自己可以新建一个另外的你可能是要去创建一个机器学习的一个名字。呃，像L demo。哦然后呢，你可以选择你的区域，然后你的存储的账户为什么要有存储呢？因为呃，在里面的话，它可以帮你去保存你的。呃，朱比特的logo还有相关的一些，呃，关于数据的整理啊，呃还有另外的一些相关的。呃，包括说训练的一些操作。还有就是一些，呃，密钥啊啊，这些都是一个非常有用的。当然你需不需要去注册一个容器了啊，也可以默认可以不用啊，在这里我们先不用，然后就开始去创建了。那在创建的过程当中，他会去也是做我们的验证的步骤。稍等，如果验证通过的话你就可以直接的去创建了。当然你的。呃。Azure machine Learning的服务呢呃，已经创建好之后呢，他就会可以告诉你去转到相关的资源里面。那大家可以看得到呃，在这里面的话，他已经把你需要的资源组已经绑定了，当然也在存储的空间还有位置上面都做了一些绑定啊，在这里面你就可以直接的去使用你的Azure machine Learning的一个平台，在这上面的话啊，我们可以根据呃情况呢去点击啊啊，这个工作室里面的URL啊，去跳转到我们的Azure机器服务的一个呃相关的一个连接，那这个时候你就可以根据你的需要。去创建爱你的呃一些公呃，跟机器学习相关的一些工作。举个例子，呃，我们做机器学习可能需要到logo。那你这个时候你可能是要去。呃。做logo的操作啊，在这里面你可以去添加啊新的logo也可以呢。呃，去在sample里面，因为你是要去学习，那你可以在上面去，呃，学习一个，呃，添加一个呃。相关的一个怎么样子去用ml experiment的操作，那这个时候呢，你可以去X sample的一个文件夹里面。啊，去把它克隆到你的本地上面。像举个例子，我在这里是一个Looking费的一个目录啊，是我的名字，然后就克隆。他就可以把呃，sample里面的文件，呃，克隆道理的呃，一个目录上面然后呢在这下面的话好像说我要去。呃，乱我的一个SDK AML的SDK，那我点击他的文件的时候大家可以发现啊，他的M啊，都是英文，比较高大上，但是不怕啊啊。在上面的话呢，呃，都是一些怎么样子去，呃，利用。嗯，这个Azure machine Learning去做一些模型训练的，那这个时候大家知道你需要去做一些相关的一些算力。呃，那你这个收了，他会告诉你你没有去做算力怎么办呢？你要去选择一个，呃，新的一个compute啊啊。在这里面你可以选择的是GPU跟CPU的compute，因为我在这里的话啊，是，呃，有你可以用一个叫做M选择GPU的时候，你可以选择的是，呃，一个M60的一个GPU的一个算力。当然你如果是节省一点的话，因为你有学生账号啊，有100刀的一个，呃，算力的一个支持。那这个时候呢，你可以选择啊，一个GPU啊啊，每个小时来算就1.58美金啊，1.5百558刀啊啊的一个算力啊。所以在这里面的话啊，你可以根据你的需要去做，而且这个呢，你不用的时候把它停掉，它是不算任何费用的。所以呢，你要看你自己的实际情况，当然你可以用CPU CPU的话呢，它有很多的cu的，呃，算力在上面像我在这里的话，我就用了一个叫做DS3 V2的一个。呃，普通的一个CPU，它是0.14刀啊呃四一刀啊呃，作为每个小时的算力那我就在这里创建创建也是虚实，呃，去创建啊。呃，它会创建成功之后就会告诉你哦，这个东西是怎么样子的，嗯。大家可以看得到哈哦你的算力也不需要去投入啊。而且呢，你可以去呃，做很多的一些机器学习相关的工作。另外呢，在这里面我想介绍给大家一个非常好玩的东西，就是他的比赛呢，我们在等待计算嗯的这个算力呃，创启动起来的时候呢，你就可以去看一下这个比赛了，这个比赛呢是什么东西呢？大家知道在Windows上面，嗯，我们可以。很简单的去拖拽一些控件去完成一些Windows的界面啊。在这里面的话呢，你可以通过啊相关的，呃，一个，呃，拖拽呃去完成机器学习里面相关的一些知识的一些创建，像我在这里的话，大家可以看到我，我选择了一个图像识别的操作之后呢，呃，如果你选择这个比赛呢，你可以看到它从图图像集啊到图像的一些转变到图像图片的一些分类。爱到训练，都是通过拖拽去完成的。这样子的话呢，他就让机器学习更加的呃，自动化啊可视化啊。呃，所以呢？呃，通过Azure的机器学习服务了你可以，呃，通过设计器去完成你的机器学习的步骤。另外的也还可以用业界最受欢迎的auto ml去完成相关的任务，也是非常方便可用的。然后我们回到我们的logo去看一下他是不是已经创建完了。好，当我们的算力创建完之后啊，大家可以看得到他会去提醒你哦，这个算力已经创建成功了然后在这个时候呢？呃，大家会担心的是，哎呀我这个算力究竟是用三者环境举个例子，你可以用的是Python 3.6的环境，当然也可以用3.8啊，还有另外的它也支持R的这种算力的一个支持。所以呢，在这里面呢是非常方便的啊，而且你可以通过呃logo的去线上的这个logo呢去添加代码。然后运行。所以呢，通过Azure machine Learning的服务呢？呃，可以让你的机器学习了的呃，学习或者实验的环境呢，得到一个提升。而且是在，呃，不用付费的前提下去完成这个事啊。希望各位同学了啊，马上去尝试一下啊。呃，通过Azure的机器学习服务去完成你的，呃，AI的学习啊，也可以作为学习的环境啊，谢谢大家。
